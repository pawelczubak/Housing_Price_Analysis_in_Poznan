# %% [markdown]
# # **Housing Price Analysis in Poznań**
#
# ## Notebook 3: Data Analysis and Visualization
# Welcome to the third notebook of the Housing Price Analysis in Poznań project.
# In this notebook, we will analyze the cleaned and structured housing dataset prepared in Notebook 2. The primary goal is to uncover insights, trends, and relationships in the housing market in Poznań.
#
# ### Objectives of this Notebook:
# 1. Perform exploratory data analysis (EDA) to understand the dataset.
# 2. Generate summary statistics for key variables like price, area, and price per square meter.
# 3. Visualize housing data to identify trends and patterns.
# 4. Derive insights based on visualizations and statistics.
#
# ---
#
# This notebook builds on the cleaned dataset produced in **Notebook 2** and provides insights into the housing market in Poznań through detailed analysis and visual storytelling. The findings here will serve as the foundation for recommendations and conclusions presented in the final phase of this project.

# %%
import pandas as pd

df = pd.read_csv('../data/processed/output_data.csv')

print(df.head())
print(df.info())
# Out:
#        City      District        Street    Price Price_per_m  Area  \
# 0  Poznań          Jeżyce  Druskienicka  598 000      11 500    52
# 1  Poznań           Wilda   Dolna Wilda  725 000      11 885    61
# 2  Poznań        Nieznana        Poznań  619 000      12 137    51
# 3  Poznań     Nowe Miasto      Os. Rusa  665 000       8 439    78
# 4  Poznań    Stare Miasto        Grobla  270 000      10 727    25
#
#    Room number  Start date Scraping date  \
# 0            2  2024-08-28    2024-12-19
# 1            3  2024-07-22    2024-12-19
# 2            2  2024-06-09    2024-12-19
# 3            3  2024-10-28    2024-12-19
# 4            1  2024-12-16    2024-12-19
#
#                                          Listing url  Floor  Floors number  \
# 0  https://gratka.pl/nieruchomosci/mieszkanie-poz...      4              4
# 1  https://gratka.pl/nieruchomosci/mieszkanie-poz...      3              4
# 2  https://gratka.pl/nieruchomosci/mieszkanie-poz...      7              7
# ...

# %%
import matplotlib.pyplot as plt

# Grupowanie danych i liczenie liczby mieszkań w każdej dzielnicy
district_counts = df['District'].value_counts()

# Tworzenie wykresu
plt.figure(figsize=(12, 6))
bars = plt.bar(district_counts.index, district_counts.values, color='skyblue', edgecolor='blue')

# Dodanie etykiet danych nad każdym słupkiem
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Pozycja X etykiety
        height,                             # Pozycja Y etykiety
        str(height),                        # Tekst etykiety
        ha='center',                        # Wyrównanie poziome
        va='bottom',                        # Wyrównanie pionowe
        fontsize=7                         # Rozmiar czcionki
    )

# Dostosowanie wykresu
plt.title('Liczba dostępnych mieszkań w każdej dzielnicy')
plt.xlabel('Dzielnica')
plt.ylabel('Liczba mieszkań')
plt.xticks(rotation=90)
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Przykładowy DataFrame (wczytaj swój plik CSV)
# df = pd.read_csv('your_file.csv')

# Konwersja kolumny 'Price' na typ numeryczny
df['Price'] = df['Price'].replace('[^\d.]', '', regex=True).astype(float)

# Grupowanie danych po 'District', obliczanie średnich cen i sortowanie malejąco
average_prices = df.groupby('District')['Price'].mean().sort_values(ascending=False)

# Tworzenie wykresu
plt.figure(figsize=(12, 6))
bars = plt.bar(average_prices.index, average_prices.values, color='skyblue', edgecolor='blue')


# Dostosowanie wykresu
plt.title('Średnie ceny mieszkań w każdej dzielnicy', fontsize=14, fontweight='bold')
plt.xlabel('Dzielnica', fontsize=12)
plt.ylabel('Średnia cena mieszkań (zł)', fontsize=12)
plt.xticks(rotation=90, fontsize=10)  # Obrót etykiet na osi X o 90 stopni
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/sq/7j71tdbs3kn4p0nqrcbfzyxr0000gn/T/ipykernel_5329/1912136966.py:8: SyntaxWarning: invalid escape sequence '\d'
#   df['Price'] = df['Price'].replace('[^\d.]', '', regex=True).astype(float)

# %%
# Konwersja kolumny 'Price_per_m' na typ numeryczny
df['Price_per_m'] = df['Price_per_m'].replace('[^\d.]', '', regex=True).astype(float)

# Grupowanie danych po 'District', obliczanie średnich cen za metr kwadratowy i sortowanie malejąco
average_price_per_m = df.groupby('District')['Price_per_m'].mean().sort_values(ascending=False)

# Tworzenie wykresu
plt.figure(figsize=(12, 6))
bars = plt.bar(average_price_per_m.index, average_price_per_m.values, color='skyblue', edgecolor='blue')



# Dostosowanie wykresu
plt.title('Średnia cena za metr kwadratowy w każdej dzielnicy', fontsize=14, fontweight='bold')
plt.xlabel('Dzielnica', fontsize=12)
plt.ylabel('Średnia cena za metr kwadratowy (zł)', fontsize=12)
plt.xticks(rotation=90, fontsize=10)  # Obrót etykiet na osi X o 90 stopni
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/sq/7j71tdbs3kn4p0nqrcbfzyxr0000gn/T/ipykernel_5329/2329454478.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df['Price_per_m'] = df['Price_per_m'].replace('[^\d.]', '', regex=True).astype(float)

# %%
# Konwersja kolumn 'Price' i 'Area' na typ numeryczny
df['Price'] = df['Price'].replace('[^\d.]', '', regex=True).astype(float)
df['Area'] = df['Area'].astype(float)

# Usunięcie wartości odstających
filtered_df = df[(df['Area'] <= 200) & (df['Price'] <= 3_000_000)]

# Tworzenie wykresu punktowego
plt.figure(figsize=(12, 6))
plt.scatter(filtered_df['Area'], filtered_df['Price'], color='blue', alpha=0.6, edgecolors='k')

# Dodanie tytułu i etykiet osi
plt.title('Zależność ceny mieszkania od powierzchni (bez wartości odstających)', fontsize=14, fontweight='bold')
plt.xlabel('Powierzchnia mieszkania (m²)', fontsize=12)
plt.ylabel('Cena mieszkania (zł)', fontsize=12)

# Dostosowanie osi
plt.grid(alpha=0.3)
plt.tight_layout()

# Wyświetlenie wykresu
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/sq/7j71tdbs3kn4p0nqrcbfzyxr0000gn/T/ipykernel_5329/3965850662.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df['Price'] = df['Price'].replace('[^\d.]', '', regex=True).astype(float)
